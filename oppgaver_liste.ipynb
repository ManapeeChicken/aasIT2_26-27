# %%
list = ["rød", "grønn", "blå"]

for i in range(len(list)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
list = [100, 120, 125, 155, 160]

for i in list:
    if i<115:
        print(i,"cm", "du er ikke høy nok for å kjøre")
    elif i<125:
        print(i,"cm", "du er ikke høy nok for å kjøre selv")
    elif i<=155:
        print(i,"cm", "du er høy nok for å kjøre alene")
# Out:
# 100 cm du er ikke høy nok for å kjøre
# 120 cm du er ikke høy nok for å kjøre selv
# 125 cm du er høy nok for å kjøre alene
# 155 cm du er høy nok for å kjøre alene

# %%
x=0
while x<=10:
    x=x+1
