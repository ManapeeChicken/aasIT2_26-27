# %% [markdown]
# ## Touch
#
#
# Touchmetoden er en metode for å skrive på maskin eller tastaturer, utviklet av rettsstenografen Frank Edgar McGurring, som underiviste i maskinskriving i Salt Lake City. Metoden baserer seg på at man finner de riktige tastene ved å bruke den taktile sansen, altså ved å kjenne hvor tastene er med fingrene fremfor å bruke synet. Skriving etter touch-metoden tar utgangspunkt i at man plasserer de åtte fingrene i en horisontal rekke midt på tastaturet, hjemmerekken eller ledetastene, og strekker fingrene etter de andre tastene ut fra denne. De fleste datatastaturer har en liten forhøyet prikk på F- og J-tasten, slik at maskinskriveren kan kjenne når fingrene hviler over riktig tast.
#
# Poenget med touchmetoden er at man skal kunne bli raskere til å skrive på keyboard.
#
# [Kilde: Wikipedia]
#
# Lenke til en treningside: https://www.keybr.com/

# %%
### UNDERSØKELSE

'''
Skriv inn GitHub-brukernavnet deres i samarbeidsområdet på OneNote. 
Når dette er lagt inn skal jeg legge dere til som contributors på IT2-repoen.
'''

# %% [markdown]
# ## Benchmarking / Prestasjonsmåling
#
# Benchmarking er i vid forstand å sammenlikne noe med et punkt man bruker som referanse, og som er definert på forhånd. Benchmarking handler altså om å sammenlikne seg med andre og lære av dette. På norsk benyttes også begrepet prestasjonsmåling.
#
# Prestasjonsmåling er løpende oppfølging av nøkkelparametre underveis i et prosjekt for å avdekke mulige problemer eller god praksis som må videreføres.
#
# Prestasjonsmåling som et verktøy for å identifisere behov for forbedringer og stimulere ønsket adferd er velkjent fra bransjer der arbeids- eller forretningsprosesser repeteres et stort antall ganger og der små forbedringer kan gi stor kumulativ effekt.
#
# [Kilde: SNL]
#
# Lenke til prestasjonsmålingsside: https://monkeytype.com/

# %%
### ØVELSE 1 ###
"""
Etter å ha trent på Touch inne på keybr, gå til monkeytype nettsiden. 
Velg parameterene for testen: Quote (type), medium (lengde), code python (språk)

Ta testen.

Noter ned resultatet ditt i parantesen i listen på følgende måte:
([wpm, acc, raw, consistency, time (i sekunder)])

Eks:
([17, 89, 27, 33, 70])

Deretter skal du laste opp resultatet til din GREN av gitHub repoen. 
OBS: Etter dette kommer den til å bli gjort privat dvs. bare elever i klassen kan lese filene.
"""

benchMk = [
    (),
]

# %%
#([19, 88, 19, 22, 58])
#([14, 82, 15, 19, 126])

# %%
import math

a=3.3
b=6.7

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(b//a)
print(b%a)
print(a**b)
print(sqrt(b))
# Out:
# 10.0
# -3.4000000000000004
# 22.11
# 0.4925373134328358
# 2.0
# 0.10000000000000053
# 2978.8140746512227
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 print(a/b)
#       8 print(b//a)
#       9 print(b%a)
#      10 print(a**b)
# ---> 11 print(sqrt(b))
#
# NameError: name 'sqrt' is not defined
